# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %%
df_summaries = pd.read_csv('data/MovieSummaries/plot_summaries.txt', sep='\t', header=None, names=['Wikipedia_ID', 'Summary'])
df_summaries = df_summaries.sample(1000)

# %%
analyzer = SentimentIntensityAnalyzer()

df_summaries['Summary_Sentiment'] = df_summaries['Summary'].apply(lambda x : analyzer.polarity_scores(x))

# %%
df_summaries['Summary_Sentiment_Compound'] = df_summaries['Summary_Sentiment'].apply(lambda x : x.get('compound'))

# %%
df_summaries['Summary_Sentiment_Compound'].sample(10)
# Out:
# 33286   -0.1531
# 19224   -0.5251
# 34801   -0.2357
# 7201    -0.9925
# 13693    0.6360
# 1066    -0.6124
# 2847    -0.8735
# 15408   -0.7906
# 4554     0.8777
# 33694    0.9866
# Name: Summary_Sentiment_Compound, dtype: float64

# %%
plt.hist(df_summaries['Summary_Sentiment_Compound'], bins = 100)
# Out:
# (array([185.,  61.,  44.,  22.,  22.,  20.,  16.,   8.,  11.,   7.,  13.,
#           6.,   5.,  10.,   9.,   7.,   5.,   1.,   1.,   5.,   4.,   5.,
#           6.,   3.,   6.,   1.,   4.,   5.,   5.,   1.,   9.,   4.,   2.,
#           1.,   6.,   3.,   3.,   4.,   9.,   6.,   3.,   2.,   6.,   2.,
#           3.,   2.,   2.,   3.,   5.,   1.,  12.,   3.,   3.,   5.,   2.,
#           3.,   3.,   1.,   3.,   0.,   3.,   5.,   2.,   3.,   6.,   7.,
#           2.,   5.,   0.,   1.,  10.,   3.,   4.,   2.,   4.,   9.,   5.,
#           5.,   3.,   3.,   9.,  10.,   4.,   6.,   3.,   5.,   7.,   9.,
#           5.,  12.,  13.,  14.,  14.,  16.,  12.,  19.,  21.,  25.,  37.,
#          68.]),
#  array([-9.99700e-01, -9.79707e-01, -9.59714e-01, -9.39721e-01,
#         -9.19728e-01, -8.99735e-01, -8.79742e-01, -8.59749e-01,
#         -8.39756e-01, -8.19763e-01, -7.99770e-01, -7.79777e-01,
#         -7.59784e-01, -7.39791e-01, -7.19798e-01, -6.99805e-01,
# ...

# %%
plt.boxplot(df_summaries['Summary_Sentiment_Compound'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1612d81d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1612d9850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x160a860d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1612dad50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1612db790>],
#  'means': []}
