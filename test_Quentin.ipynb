# %%
import src.models.question1 as q1
import src.models.question2 as q2
import src.models.question3 as q3
import src.models.question4 as q4
import src.models.question5 as q5
import src.models.question6 as q6

# %load_ext autoreload
# %autoreload 2

# %%
q5.get_data()
# Out:
#        Unnamed: 0                                           title  \
# 0               0                                            Hype
# 1               1                                           Great
# 2               2                      I could watch it every day
# 3               3  The Coen Brothers come up with another winner.
# 4               4                          The best film of 1996.
# ...           ...                                             ...
# 40145       40145                           Southern Trip Adviser
# 40146       40146                  Not sure what to make of this.
# 40147       40147                         Surreal magical realism
# 40148       40148                 An Unconventional Story of Love
# 40149       40149                It May Require A Second Viewing!
#
#                                                     text  rating       date  \
# 0      This movie does not live up to the hype. It's ...     6.0 1998-07-29
# ...

# %%
result_df = q5.perform_statistical_tests()
# Out:
# There are 20 rejected movies (p-value < 0.05). That represents only 30.303030303030305 percent of the movies

# %%
# 4 / 9
result_df.loc[result_df['Winner'] == True]
# Out:
#      Movie ID  Winner   p-value
# 9   tt0172495    True  0.204171
# 15  tt0268978    True  0.206352
# 27  tt0405159    True  0.241360
# 28  tt0407887    True  0.027680
# 37  tt0477348    True  0.351262
# 47  tt1010048    True  0.004471
# 50  tt1024648    True  0.038036
# 61  tt1504320    True  0.028927
# 64  tt1655442    True  0.971828

# %%
# 16 / 66
result_df.loc[(result_df['Winner'] == False) & (result_df['p-value'] < 0.05)]
# Out:
#      Movie ID  Winner       p-value
# 0   tt0120689   False  4.748418e-02
# 1   tt0120737   False  7.671991e-03
# 6   tt0140352   False  2.168102e-02
# 10  tt0190332   False  1.905200e-09
# 19  tt0311113   False  6.403260e-03
# 24  tt0361748   False  1.248491e-03
# 25  tt0375063   False  1.675194e-02
# 26  tt0388795   False  1.913627e-03
# 32  tt0449059   False  1.536039e-02
# 35  tt0467406   False  3.328548e-04
# 36  tt0469494   False  1.285000e-02
# 38  tt0478304   False  2.217496e-02
# 44  tt0947798   False  1.632685e-03
# 56  tt1210166   False  2.278675e-02
# 57  tt1285016   False  4.121225e-02
# 58  tt1375666   False  2.704475e-05

# %% [markdown]
# Movies that win oscar seem to create a change in the average sentiment score more often
