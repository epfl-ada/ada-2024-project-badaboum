# %%
import pandas as pd

# %%
PATH = 'data/'
titles = pd.read_csv(PATH + 'title.basics.tsv',sep='\t')
titles.head()
# Out:
# /tmp/ipykernel_108528/741945459.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   titles = pd.read_csv(PATH + 'title.basics.tsv',sep='\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# ...

# %%
len(titles)
# Out:
# 11201577

# %%
ratings = pd.read_csv(PATH + 'title.ratings.tsv',sep='\t')
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2096
# 1  tt0000002            5.6       282
# 2  tt0000003            6.5      2110
# 3  tt0000004            5.4       182
# 4  tt0000005            6.2      2843

# %%
len(ratings)
# Out:
# 1493420

# %%
df = pd.merge(titles, ratings, on = 'tconst')

# %%
df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres  \
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7      2096
# 1            5.6       282
# 2            6.5      2110
# ...

# %%
df.tail()
# Out:
#             tconst  titleType                primaryTitle  \
# 1493415  tt9916730      movie                      6 Gunn
# 1493416  tt9916766  tvEpisode              Episode #10.15
# 1493417  tt9916778  tvEpisode                      Escape
# 1493418  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1493419  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 1493415                      6 Gunn       0      2017      \N            116
# 1493416              Episode #10.15       0      2019      \N             43
# 1493417                      Escape       0      2019      \N             \N
# 1493418  Horrid Henry's Comic Caper       0      2014      \N             11
# 1493419   Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres  averageRating  numVotes
# 1493415                        Drama            7.0        12
# ...

# %%
#TODO: add a column to the df which states if it was nominated and if it won (like a 0/1 column)
